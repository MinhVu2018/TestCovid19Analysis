# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# data source:
# https://ourworldindata.org/coronavirus/country/vietnam
# https://data.opendevelopmentmekong.net//dataset/coronavirus-covid-19-cases-in-vietnam

# %%
data = pd.read_csv(r"owid-covid-data.csv")

# %%
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %%
data.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  9.276500e+04   92762.000000        91752.000000  8.274600e+04
# mean   1.001918e+06    6051.988142         6083.568842  2.745539e+04
# std    6.892250e+06   38000.421108        37768.864977  1.636109e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.175000e+03       2.000000            7.286000  5.200000e+01
# 50%    1.281700e+04      73.000000           90.642500  3.590000e+02
# 75%    1.353670e+05     800.000000          839.464500  3.525500e+03
# max    1.766438e+08  906008.000000       826389.571000  3.822698e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  82902.000000         91752.000000             92270.000000
# mean     147.187486           132.001725             12320.548622
# std      805.166930           745.813251             22938.610697
# min    -1918.000000          -232.143000                 0.001000
# ...

# %%
data.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
VN_data = data.loc[data['location'] == 'Vietnam']
VN_data
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 93555      VNM      Asia  Vietnam  2020-01-23          2.0        2.0
# 93556      VNM      Asia  Vietnam  2020-01-24          2.0        0.0
# 93557      VNM      Asia  Vietnam  2020-01-25          2.0        0.0
# 93558      VNM      Asia  Vietnam  2020-01-26          2.0        0.0
# 93559      VNM      Asia  Vietnam  2020-01-27          2.0        0.0
# ...        ...       ...      ...         ...          ...        ...
# 94060      VNM      Asia  Vietnam  2021-06-11      10048.0      213.0
# 94061      VNM      Asia  Vietnam  2021-06-12      10337.0      289.0
# 94062      VNM      Asia  Vietnam  2021-06-13      10630.0      293.0
# 94063      VNM      Asia  Vietnam  2021-06-14      10881.0      251.0
# 94064      VNM      Asia  Vietnam  2021-06-15      11304.0      423.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# VN_data.dropna(axis=1)
VN_data = VN_data.dropna(axis=1, how='all')

# %%
VN_data.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'new_tests',
#        'total_tests', 'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
# ...

# %%
VN_data = VN_data[['date', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'total_tests', 'new_tests', 'total_vaccinations', 'new_vaccinations', 'population']]
VN_data.fillna(0)
# Out:
#              date  total_cases  new_cases  total_deaths  new_deaths  \
# 93555  2020-01-23          2.0        2.0           0.0         0.0
# 93556  2020-01-24          2.0        0.0           0.0         0.0
# 93557  2020-01-25          2.0        0.0           0.0         0.0
# 93558  2020-01-26          2.0        0.0           0.0         0.0
# 93559  2020-01-27          2.0        0.0           0.0         0.0
# ...           ...          ...        ...           ...         ...
# 94060  2021-06-11      10048.0      213.0          57.0         2.0
# 94061  2021-06-12      10337.0      289.0          58.0         1.0
# 94062  2021-06-13      10630.0      293.0          59.0         1.0
# 94063  2021-06-14      10881.0      251.0          59.0         0.0
# 94064  2021-06-15      11304.0      423.0          61.0         2.0
#
#        total_tests  new_tests  total_vaccinations  new_vaccinations
# 93555          0.0        0.0                 0.0               0.0
# ...

# %%
sns.relplot(x='date', y='total_cases', data = VN_data)

# %%
sns.pairplot(VN_data)

# %%
sns.relplot(x='date', y='total_deaths', kind='line', data = VN_data)

# %%
sns.catplot(x='date', y='total_vaccinations', data = VN_data)

# %%
df1 = VN_data[['new_cases']]
df2 = VN_data[['new_deaths']]
ax = df1.plot()

df2.plot(ax=ax)
# Out:
# <AxesSubplot:>

# %%
VN_data_02 = data.loc[data['location'] == 'Vietnam']
VN_data_02 = VN_data_02.dropna(axis=1, how='all')
VN_data_02
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 93555      VNM      Asia  Vietnam  2020-01-23          2.0        2.0
# 93556      VNM      Asia  Vietnam  2020-01-24          2.0        0.0
# 93557      VNM      Asia  Vietnam  2020-01-25          2.0        0.0
# 93558      VNM      Asia  Vietnam  2020-01-26          2.0        0.0
# 93559      VNM      Asia  Vietnam  2020-01-27          2.0        0.0
# ...        ...       ...      ...         ...          ...        ...
# 94060      VNM      Asia  Vietnam  2021-06-11      10048.0      213.0
# 94061      VNM      Asia  Vietnam  2021-06-12      10337.0      289.0
# 94062      VNM      Asia  Vietnam  2021-06-13      10630.0      293.0
# 94063      VNM      Asia  Vietnam  2021-06-14      10881.0      251.0
# 94064      VNM      Asia  Vietnam  2021-06-15      11304.0      423.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
VN_data_02.nunique(axis=0)
# Out:
# iso_code                                   1
# continent                                  1
# location                                   1
# date                                     510
# total_cases                              373
# new_cases                                 82
# new_cases_smoothed                       167
# total_deaths                              39
# new_deaths                                 5
# new_deaths_smoothed                       14
# total_cases_per_million                  373
# new_cases_per_million                     82
# new_cases_smoothed_per_million           167
# total_deaths_per_million                  39
# new_deaths_per_million                     5
# new_deaths_smoothed_per_million           14
# reproduction_rate                        139
# new_tests                                 73
# total_tests                              106
# total_tests_per_thousand                  98
# new_tests_per_thousand                    49
# ...
